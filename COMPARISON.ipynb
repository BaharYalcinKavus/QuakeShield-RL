# %%
# !pip install ortools openpyxl pandas
# Out:
# Requirement already satisfied: ortools in /usr/local/lib/python3.12/dist-packages (9.14.6206)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: absl-py>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ortools) (2.3.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from ortools) (2.0.2)
# Requirement already satisfied: protobuf<6.32,>=6.31.1 in /usr/local/lib/python3.12/dist-packages (from ortools) (6.31.1)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from ortools) (4.15.0)
# Requirement already satisfied: immutabledict>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from ortools) (4.2.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# -*- coding: utf-8 -*-
"""
Capacitated VRP (CVRP) - OR-Tools versiyonu
- Mesafe matrisi Excel'den okunuyor: /content/kcekmece_distance.xlsx
- 0 mesafeli (i != j) girişler 'yol yok' olarak kabul edilip BIG_M cezası veriliyor.
- MANDATORY_NODES: talebi 1 olan düğümler (diğer tüm düğümler talep=0).
- VEHICLE_CAPACITIES: araç kapasite vektörü.
"""

import pandas as pd
import numpy as np
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

# ==============================
# KULLANICI PARAMETRELERİ
# ==============================

EXCEL_PATH = "/content/kcekmece_distance.xlsx"
SHEET_NAME = "Sheet1"

# Depo index'i (Excel'deki node indekslerine göre)
DEPOT = 77  # örnek

# 1 birim talep olan düğümler (diğer tüm node'lar 0 talep)
# -> Bunları kendi senaryona göre değiştir!
MANDATORY_NODES = [464, 573, 607, 699]
# Araç kapasiteleri (her eleman o aracın max toplam talebi)
VEHICLE_CAPACITIES = [1, 1, 1, 1] # toplam = len(MANDATORY_NODES) olmasını istiyorsan buna göre ayarla
NUM_VEHICLES = len(VEHICLE_CAPACITIES)


# ==============================
# MESAFE MATRİSİ YARDIMCI FONKSİYONLAR
# ==============================

def load_distance_matrix_xlsx(path, sheet_name="Sheet1"):
    """Excel'den kare mesafe matrisi oku, gereksiz boş satır/sütunları temizle."""
    df = pd.read_excel(path, sheet_name=sheet_name, header=None)

    # Baştaki tamamen boş satırları temizle
    while df.shape[0] > 0 and df.iloc[0].isna().all():
        df = df.iloc[1:, :].reset_index(drop=True)

    # Baştaki tamamen boş sütunları temizle
    while df.shape[1] > 0 and df.iloc[:, 0].isna().all():
        df = df.iloc[:, 1:].reset_index(drop=True)

    df = df.apply(pd.to_numeric, errors='coerce').fillna(0.0)
    assert df.shape[0] == df.shape[1], f"Mesafe matrisi kare olmalı, şu an: {df.shape}"
    arr = df.values.astype(np.float64)

    # Diagonal 0
    n = arr.shape[0]
    for i in range(n):
        arr[i, i] = 0.0

    return arr


def preprocess_distance_matrix(dm_raw, multiplier=1000.0):
    """
    Orijinal dm_raw'dan OR-Tools'a uygun distance_matrix üretir:
    - i == j  -> 0
    - i != j ve dm_raw[i,j] > 0 -> int(round(dm_raw[i,j]))
    - i != j ve dm_raw[i,j] <= 0 -> BIG_M (yol yok / bilinmeyen)
    BIG_M = max_pozitif_mesafe * multiplier
    """
    arr = dm_raw.copy().astype(np.float64)
    n = arr.shape[0]

    positive = arr[arr > 0]
    if positive.size == 0:
        raise ValueError("Mesafe matrisinde pozitif değer yok, BIG_M seçilemedi.")

    # max_dist = float(positive.max())
    # big_m = int(max_dist * multiplier)
    big_m = 2500

    dm_int = np.zeros((n, n), dtype=np.int64)
    for i in range(n):
        for j in range(n):
            if i == j:
                dm_int[i, j] = 0
            else:
                val = arr[i, j]
                if val <= 0.0:
                    # Yol yok / 0 girilmiş -> devasa ceza
                    dm_int[i, j] = big_m
                else:
                    dm_int[i, j] = int(round(val))

    return dm_int, big_m


# ==============================
# DATA MODEL
# ==============================

def create_data_model():
    """Problemin verisini hazırlar (distance, demand, kapasite, depot, vs.)."""
    # 1) Excel'den ham mesafe matrisi
    print("[INFO] Excel'den mesafe matrisi okunuyor...")
    dm_raw = load_distance_matrix_xlsx(EXCEL_PATH, sheet_name=SHEET_NAME)
    n = dm_raw.shape[0]
    print(f"[INFO] Matris boyutu: {n} x {n}")

    # 2) BIG_M'li integer mesafe matrisi (0 -> BIG_M)
    distance_matrix_int, big_m = preprocess_distance_matrix(dm_raw, multiplier=1000.0)
    print(f"[INFO] BIG_M (yol yok cezası) = {big_m}")

    # 3) MANDATORY_NODES kontrol
    for idx in MANDATORY_NODES:
        if idx < 0 or idx >= n:
            raise ValueError(f"MANDATORY_NODES içindeki {idx} index'i matris boyutu {n} ile uyumsuz!")

    if DEPOT < 0 or DEPOT >= n:
        raise ValueError(f"DEPOT index'i ({DEPOT}) matris boyutu {n} ile uyumsuz!")

    # 4) Talep vektörü:
    #    - Default: tüm node'lar 0
    #    - MANDATORY_NODES: 1 birim talep
    demands = [0] * n
    for idx in MANDATORY_NODES:
        if idx == DEPOT:
            # Depo talep node olmasın, ama istersen burayı 0 bırakmak mantıklı
            print(f"[UYARI] MANDATORY_NODES içinde depo ({DEPOT}) var, talep atlanıyor.")
            continue
        demands[idx] = 1

    total_demand = sum(demands)
    total_capacity = sum(int(c) for c in VEHICLE_CAPACITIES)

    print(f"[INFO] Toplam talep            : {total_demand}")
    print(f"[INFO] Toplam araç kapasitesi  : {total_capacity}")
    print(f"[INFO] Araç kapasiteleri       : {VEHICLE_CAPACITIES}")
    print(f"[INFO] Depo (index)            : {DEPOT}")

    if total_capacity < total_demand:
        raise ValueError(
            f"Toplam kapasite ({total_capacity}), toplam talebin ({total_demand}) altında! "
            f"Araç kapasitelerini arttır."
        )

    data = {}
    data["distance_matrix"] = distance_matrix_int.tolist()
    data["dm_raw"] = dm_raw  # istersen sonradan orijinal mesafeyi görmek için
    data["big_m"] = big_m
    data["demands"] = demands
    data["vehicle_capacities"] = [int(c) for c in VEHICLE_CAPACITIES]
    data["num_vehicles"] = NUM_VEHICLES
    data["depot"] = DEPOT
    return data


# ==============================
# ÇÖZÜM YAZDIRMA
# ==============================

def print_solution(data, manager, routing, solution):
    """Çözümü konsola yazdırır."""
    print(f"\nObjective (toplam maliyet): {solution.ObjectiveValue()}")
    total_distance = 0
    total_load = 0

    distance_matrix = data["distance_matrix"]
    dm_raw = data["dm_raw"]
    big_m = data["big_m"]

    for vehicle_id in range(data["num_vehicles"]):
        # Kullanılmayan aracı atla (OR-Tools gereksiz aracı boş bırakabilir)
        if not routing.IsVehicleUsed(solution, vehicle_id):
            print(f"\n[INFO] Vehicle {vehicle_id} kullanılmadı.")
            continue

        index = routing.Start(vehicle_id)
        plan_output = f"\nRoute for vehicle {vehicle_id}:\n"
        route_distance = 0
        route_load = 0

        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            demand_here = data["demands"][node_index]
            route_load += demand_here
            plan_output += f" {node_index} (demand={demand_here}, load={route_load}) -> "

            previous_index = index
            index = solution.Value(routing.NextVar(index))

            # Arc cost (cezalı mesafe)
            arc_cost = routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
            route_distance += arc_cost

        # Son node (depot)
        end_node = manager.IndexToNode(index)
        plan_output += f" {end_node} (demand=0, load={route_load})\n"
        plan_output += f"Distance of the route (model cost): {route_distance}\n"
        plan_output += f"Load of the route: {route_load}\n"
        print(plan_output)

        total_distance += route_distance
        total_load += route_load

    print(f"\nTotal distance of all routes (model cost): {total_distance}")
    print(f"Total load of all routes: {total_load}")

    # İsteğe bağlı: BIG_M kullanılan kenarları uyarı olarak göster
    print("\n[CHECK] BIG_M kullanılan (yol yok) edge var mı?")
    used_big_m_edges = []
    for vehicle_id in range(data["num_vehicles"]):
        if not routing.IsVehicleUsed(solution, vehicle_id):
            continue
        index = routing.Start(vehicle_id)
        while not routing.IsEnd(index):
            from_index = index
            to_index = solution.Value(routing.NextVar(index))
            from_node = manager.IndexToNode(from_index)
            to_node = manager.IndexToNode(to_index)
            if from_node != to_node:
                model_dist = distance_matrix[from_node][to_node]
                if model_dist >= big_m:
                    used_big_m_edges.append((vehicle_id, from_node, to_node))
            index = to_index

    if used_big_m_edges:
        print("\n[UYARI] Aşağıdaki kenarlarda BIG_M kullanıldı (orijinal dm_raw'da mesafe <= 0):")
        for (vid, u, v) in used_big_m_edges:
            print(f"  Vehicle {vid}: {u} -> {v} | dm_raw[{u},{v}] = {dm_raw[u, v]}")
    else:
        print("[INFO] Hiçbir araç rotasında BIG_M (yol yok) kenarı kullanılmadı.")


# ==============================
# MAIN: CVRP ÇÖZ
# ==============================

def main():
    # Veriyi hazırla
    data = create_data_model()

    # Routing index manager
    manager = pywrapcp.RoutingIndexManager(
        len(data["distance_matrix"]), data["num_vehicles"], data["depot"]
    )

    # Routing model
    routing = pywrapcp.RoutingModel(manager)

    # Mesafe callback'i
    def distance_callback(from_index, to_index):
        """İki node arasındaki mesafeyi döner (BIG_M'li integer)."""
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data["distance_matrix"][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Tüm araçlar için arc maliyeti
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Talep callback'i
    def demand_callback(from_index):
        """Node'un talebini döner."""
        from_node = manager.IndexToNode(from_index)
        return data["demands"][from_node]

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)

    # Kapasite kısıtı
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,  # slack
        data["vehicle_capacities"],  # kapasite vektörü
        True,  # start cumul to zero
        "Capacity",
    )

    # İlk çözüm + local search stratejileri
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
    )
    search_parameters.local_search_metaheuristic = (
        routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH
    )
    # Süre limiti (saniye)
    search_parameters.time_limit.FromSeconds(180)

    # Çöz
    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        print_solution(data, manager, routing, solution)
    else:
        print("Çözüm bulunamadı! (Belki kapasite çok düşük, ya da BIG_M çok agresif)")

# Çalıştır
if __name__ == "__main__":
    main()
# Out:
# [INFO] Excel'den mesafe matrisi okunuyor...
# [INFO] Matris boyutu: 822 x 822
# [INFO] BIG_M (yol yok cezası) = 2500
# [INFO] Toplam talep            : 4
# [INFO] Toplam araç kapasitesi  : 4
# [INFO] Araç kapasiteleri       : [1, 1, 1, 1]
# [INFO] Depo (index)            : 77
#
# Objective (toplam maliyet): 230223
#
# Route for vehicle 0:
#  77 (demand=0, load=0) ->  453 (demand=0, load=0) ->  451 (demand=0, load=0) ->  452 (demand=0, load=0) ->  697 (demand=0, load=0) ->  698 (demand=0, load=0) ->  109 (demand=0, load=0) ->  622 (demand=0, load=0) ->  621 (demand=0, load=0) ->  620 (demand=0, load=0) ->  619 (demand=0, load=0) ->  497 (demand=0, load=0) ->  494 (demand=0, load=0) ->  772 (demand=0, load=0) ->  767 (demand=0, load=0) ->  771 (demand=0, load=0) ->  459 (demand=0, load=0) ->  454 (demand=0, load=0) ->  455 (demand=0, load=0) ->  457 (demand=0, load=0) ->  458 (demand=0, load=0) ->  445 (demand=0, load=0) ->  450 (demand=0, load=0) ->  442 (demand=0, load=0) ->  448 (demand=0, load=0) ->  449 (demand=0, load=0) ->  446 (demand=0, load=0) ->  456 (demand=0, load=0) ->  447 (demand=0, load=0) ->  443 (demand=0, load=0) ->  568 (demand=0, load=0) ->  275 (demand=0, load=0) ->  630 (demand=0, load=0) ->  565 (demand=0, load=0) ->  495 (demand=0, load=0) ->  441 (demand=0, load=0) ->  444 (demand=0, load=0) ->  686 (demand=0, load=0) ->  222 (demand=0, load=0) ->  220 (demand=0, load=0) ->  188 (demand=0, load=0) ->  246 (demand=0, load=0) ->  176 (demand=0, load=0) ->  691 (demand=0, load=0) ->  659 (demand=0, load=0) ->  553 (demand=0, load=0) ->  228 (demand=0, load=0) ->  422 (demand=0, load=0) ->  670 (demand=0, load=0) ->  421 (demand=0, load=0) ->  408 (demand=0, load=0) ->  745 (demand=0, load=0) ->  403 (demand=0, load=0) ->  81 (demand=0, load=0) ->  435 (demand=0, load=0) ->  405 (demand=0, load=0) ->  409 (demand=0, load=0) ->  469 (demand=0, load=0) ->  432 (demand=0, load=0) ->  428 (demand=0, load=0) ->  80 (demand=0, load=0) ->  420 (demand=0, load=0) ->  678 (demand=0, load=0) ->  345 (demand=0, load=0) ->  627 (demand=0, load=0) ->  365 (demand=0, load=0) ->  280 (demand=0, load=0) ->  348 (demand=0, load=0) ->  344 (demand=0, load=0) ->  628 (demand=0, load=0) ->  279 (demand=0, load=0) ->  567 (demand=0, load=0) ->  562 (demand=0, load=0) ->  566 (demand=0, load=0) ->  499 (demand=0, load=0) ->  305 (demand=0, load=0) ->  669 (demand=0, load=0) ->  564 (demand=0, load=0) ->  563 (demand=0, load=0) ->  629 (demand=0, load=0) ->  668 (demand=0, load=0) ->  163 (demand=0, load=0) ->  162 (demand=0, load=0) ->  155 (demand=0, load=0) ->  170 (demand=0, load=0) ->  137 (demand=0, load=0) ->  209 (demand=0, load=0) ->  136 (demand=0, load=0) ->  230 (demand=0, load=0) ->  387 (demand=0, load=0) ->  0 (demand=0, load=0) ->  664 (demand=0, load=0) ->  646 (demand=0, load=0) ->  308 (demand=0, load=0) ->  810 (demand=0, load=0) ->  674 (demand=0, load=0) ->  318 (demand=0, load=0) ->  284 (demand=0, load=0) ->  544 (demand=0, load=0) ->  509 (demand=0, load=0) ->  322 (demand=0, load=0) ->  311 (demand=0, load=0) ->  293 (demand=0, load=0) ->  283 (demand=0, load=0) ->  295 (demand=0, load=0) ->  289 (demand=0, load=0) ->  819 (demand=0, load=0) ->  820 (demand=0, load=0) ->  781 (demand=0, load=0) ->  784 (demand=0, load=0) ->  785 (demand=0, load=0) ->  786 (demand=0, load=0) ->  779 (demand=0, load=0) ->  778 (demand=0, load=0) ->  787 (demand=0, load=0) ->  788 (demand=0, load=0) ->  777 (demand=0, load=0) ->  775 (demand=0, load=0) ->  776 (demand=0, load=0) ->  792 (demand=0, load=0) ->  774 (demand=0, load=0) ->  773 (demand=0, load=0) ->  789 (demand=0, load=0) ->  800 (demand=0, load=0) ->  799 (demand=0, load=0) ->  798 (demand=0, load=0) ->  797 (demand=0, load=0) ->  796 (demand=0, load=0) ->  780 (demand=0, load=0) ->  581 (demand=0, load=0) ->  580 (demand=0, load=0) ->  316 (demand=0, load=0) ->  364 (demand=0, load=0) ->  653 (demand=0, load=0) ->  313 (demand=0, load=0) ->  503 (demand=0, load=0) ->  349 (demand=0, load=0) ->  346 (demand=0, load=0) ->  366 (demand=0, load=0) ->  331 (demand=0, load=0) ->  336 (demand=0, load=0) ->  794 (demand=0, load=0) ->  795 (demand=0, load=0) ->  783 (demand=0, load=0) ->  782 (demand=0, load=0) ->  303 (demand=0, load=0) ->  511 (demand=0, load=0) ->  607 (demand=1, load=1) ->  604 (dem ...
# Distance of the route (model cost): 95000
# Load of the route: 1
#
#
# Route for vehicle 1:
#  77 (demand=0, load=0) ->  658 (demand=0, load=0) ->  657 (demand=0, load=0) ->  661 (demand=0, load=0) ->  656 (demand=0, load=0) ->  811 (demand=0, load=0) ->  821 (demand=0, load=0) ->  693 (demand=0, load=0) ->  31 (demand=0, load=0) ->  194 (demand=0, load=0) ->  692 (demand=0, load=0) ->  430 (demand=0, load=0) ->  701 (demand=0, load=0) ->  699 (demand=1, load=1) ->  704 (demand=0, load=1) ->  3 (demand=0, load=1) ->  376 (demand=0, load=1) ->  362 (demand=0, load=1) ->  4 (demand=0, load=1) ->  5 (demand=0, load=1) ->  6 (demand=0, load=1) ->  649 (demand=0, load=1) ->  339 (demand=0, load=1) ->  7 (demand=0, load=1) ->  354 (demand=0, load=1) ->  648 (demand=0, load=1) ->  42 (demand=0, load=1) ->  651 (demand=0, load=1) ->  436 (demand=0, load=1) ->  650 (demand=0, load=1) ->  55 (demand=0, load=1) ->  54 (demand=0, load=1) ->  633 (demand=0, load=1) ->  634 (demand=0, load=1) ->  90 (demand=0, load=1) ->  603 (demand=0, load=1) ->  2 (demand=0, load=1) ->  561 (demand=0, load=1) ->  479 (demand=0, load=1) ->  368 (demand=0, load=1) ->  374 (demand=0, load=1) ->  352 (demand=0, load=1) ->  332 (demand=0, load=1) ->  350 (demand=0, load=1) ->  478 (demand=0, load=1) ->  328 (demand=0, load=1) ->  363 (demand=0, load=1) ->  371 (demand=0, load=1) ->  347 (demand=0, load=1) ->  372 (demand=0, load=1) ->  330 (demand=0, load=1) ->  361 (demand=0, load=1) ->  357 (demand=0, load=1) ->  326 (demand=0, load=1) ->  343 (demand=0, load=1) ->  358 (demand=0, load=1) ->  262 (demand=0, load=1) ->  595 (demand=0, load=1) ->  597 (demand=0, load=1) ->  596 (demand=0, load=1) ->  546 (demand=0, load=1) ->  602 (demand=0, load=1) ->  594 (demand=0, load=1) ->  290 (demand=0, load=1) ->  306 (demand=0, load=1) ->  310 (demand=0, load=1) ->  593 (demand=0, load=1) ->  276 (demand=0, load=1) ->  282 (demand=0, load=1) ->  267 (demand=0, load=1) ->  702 (demand=0, load=1) ->  703 (demand=0, load=1) ->  333 (demand=0, load=1) ->  462 (demand=0, load=1) ->  377 (demand=0, load=1) ->  130 (demand=0, load=1) ->  521 (demand=0, load=1) ->  522 (demand=0, load=1) ->  115 (demand=0, load=1) ->  756 (demand=0, load=1) ->  502 (demand=0, load=1) ->  757 (demand=0, load=1) ->  758 (demand=0, load=1) ->  753 (demand=0, load=1) ->  759 (demand=0, load=1) ->  760 (demand=0, load=1) ->  754 (demand=0, load=1) ->  477 (demand=0, load=1) ->  755 (demand=0, load=1) ->  112 (demand=0, load=1) ->  655 (demand=0, load=1) ->  113 (demand=0, load=1) ->  433 (demand=0, load=1) ->  114 (demand=0, load=1) ->  419 (demand=0, load=1) ->  417 (demand=0, load=1) ->  434 (demand=0, load=1) ->  424 (demand=0, load=1) ->  416 (demand=0, load=1) ->  413 (demand=0, load=1) ->  803 (demand=0, load=1) ->  219 (demand=0, load=1) ->  190 (demand=0, load=1) ->  802 (demand=0, load=1) ->  231 (demand=0, load=1) ->  191 (demand=0, load=1) ->  169 (demand=0, load=1) ->  440 (demand=0, load=1) ->  663 (demand=0, load=1) ->  662 (demand=0, load=1) ->  806 (demand=0, load=1) ->  804 (demand=0, load=1) ->  805 (demand=0, load=1) ->  766 (demand=0, load=1) ->  94 (demand=0, load=1) ->  746 (demand=0, load=1) ->  765 (demand=0, load=1) ->  431 (demand=0, load=1) ->  407 (demand=0, load=1) ->  426 (demand=0, load=1) ->  423 (demand=0, load=1) ->  427 (demand=0, load=1) ->  411 (demand=0, load=1) ->  677 (demand=0, load=1) ->  507 (demand=0, load=1) ->  508 (demand=0, load=1) ->  506 (demand=0, load=1) ->  510 (demand=0, load=1) ->  505 (demand=0, load=1) ->  809 (demand=0, load=1) ->  808 (demand=0, load=1) ->  807 (demand=0, load=1) ->  468 (demand=0, load=1) ->  77 (demand=0, load=1)
# Distance of the route (model cost): 44398
# Load of the route: 1
#
#
# Route for vehicle 2:
#  77 (demand=0, load=0) ->  118 (demand=0, load=0) ->  570 (demand=0, load=0) ->  123 (demand=0, load=0) ->  120 (demand=0, load=0) ->  117 (demand=0, load=0) ->  234 (demand=0, load=0) ->  153 (demand=0, load=0) ->  154 (demand=0, load=0) ->  223 (demand=0, load=0) ->  149 (demand=0, load=0) ->  256 (demand=0, load=0) ->  237 (demand=0, load=0) ->  213 (demand=0, load=0) ->  685 (demand=0, load=0) ->  684 (demand=0, load=0) ->  707 (demand=0, load=0) ->  89 (demand=0, load=0) ->  518 (demand=0, load=0) ->  736 (demand=0, load=0) ->  312 (demand=0, load=0) ->  317 (demand=0, load=0) ->  527 (demand=0, load=0) ->  583 (demand=0, load=0) ->  584 (demand=0, load=0) ->  530 (demand=0, load=0) ->  301 (demand=0, load=0) ->  569 (demand=0, load=0) ->  531 (demand=0, load=0) ->  288 (demand=0, load=0) ->  529 (demand=0, load=0) ->  528 (demand=0, load=0) ->  516 (demand=0, load=0) ->  735 (demand=0, load=0) ->  734 (demand=0, load=0) ->  394 (demand=0, load=0) ->  389 (demand=0, load=0) ->  396 (demand=0, load=0) ->  388 (demand=0, load=0) ->  378 (demand=0, load=0) ->  476 (demand=0, load=0) ->  475 (demand=0, load=0) ->  62 (demand=0, load=0) ->  61 (demand=0, load=0) ->  466 (demand=0, load=0) ->  613 (demand=0, load=0) ->  390 (demand=0, load=0) ->  762 (demand=0, load=0) ->  761 (demand=0, load=0) ->  399 (demand=0, load=0) ->  146 (demand=0, load=0) ->  87 (demand=0, load=0) ->  676 (demand=0, load=0) ->  675 (demand=0, load=0) ->  167 (demand=0, load=0) ->  159 (demand=0, load=0) ->  32 (demand=0, load=0) ->  694 (demand=0, load=0) ->  612 (demand=0, load=0) ->  716 (demand=0, load=0) ->  715 (demand=0, load=0) ->  714 (demand=0, load=0) ->  713 (demand=0, load=0) ->  712 (demand=0, load=0) ->  710 (demand=0, load=0) ->  711 (demand=0, load=0) ->  116 (demand=0, load=0) ->  625 (demand=0, load=0) ->  624 (demand=0, load=0) ->  524 (demand=0, load=0) ->  525 (demand=0, load=0) ->  496 (demand=0, load=0) ->  315 (demand=0, load=0) ->  623 (demand=0, load=0) ->  667 (demand=0, load=0) ->  101 (demand=0, load=0) ->  493 (demand=0, load=0) ->  618 (demand=0, load=0) ->  526 (demand=0, load=0) ->  671 (demand=0, load=0) ->  110 (demand=0, load=0) ->  111 (demand=0, load=0) ->  523 (demand=0, load=0) ->  705 (demand=0, load=0) ->  706 (demand=0, load=0) ->  739 (demand=0, load=0) ->  738 (demand=0, load=0) ->  582 (demand=0, load=0) ->  296 (demand=0, load=0) ->  320 (demand=0, load=0) ->  574 (demand=0, load=0) ->  300 (demand=0, load=0) ->  321 (demand=0, load=0) ->  638 (demand=0, load=0) ->  44 (demand=0, load=0) ->  48 (demand=0, load=0) ->  517 (demand=0, load=0) ->  49 (demand=0, load=0) ->  647 (demand=0, load=0) ->  532 (demand=0, load=0) ->  533 (demand=0, load=0) ->  285 (demand=0, load=0) ->  50 (demand=0, load=0) ->  51 (demand=0, load=0) ->  304 (demand=0, load=0) ->  278 (demand=0, load=0) ->  598 (demand=0, load=0) ->  599 (demand=0, load=0) ->  273 (demand=0, load=0) ->  272 (demand=0, load=0) ->  281 (demand=0, load=0) ->  287 (demand=0, load=0) ->  309 (demand=0, load=0) ->  660 (demand=0, load=0) ->  88 (demand=0, load=0) ->  589 (demand=0, load=0) ->  592 (demand=0, load=0) ->  591 (demand=0, load=0) ->  307 (demand=0, load=0) ->  587 (demand=0, load=0) ->  294 (demand=0, load=0) ->  514 (demand=0, load=0) ->  542 (demand=0, load=0) ->  543 (demand=0, load=0) ->  545 (demand=0, load=0) ->  541 (demand=0, load=0) ->  515 (demand=0, load=0) ->  274 (demand=0, load=0) ->  302 (demand=0, load=0) ->  53 (demand=0, load=0) ->  637 (demand=0, load=0) ->  43 (demand=0, load=0) ->  46 (demand=0, load=0) ->  47 (demand=0, load=0) ->  314 (demand=0, load=0) ->  297 (demand=0, load=0) ->  299 (demand=0, load=0) ->  268 (demand=0, load=0) ->  270 (demand=0, load=0) ->  600 (demand=0, load=0) ->  601 (demand=0, load=0) ->  539 (demand=0, load=0) ->  9 (demand=0, load=0) ->  292 (demand=0, load=0) ->  266 (demand=0, load=0) ->  512 (demand=0, load=0) ->  45 (demand=0, load=0) ->  8 (demand=0, load=0) ->  323 (demand=0, load=0) - ...
# Distance of the route (model cost): 83529
# Load of the route: 1
#
#
# Route for vehicle 3:
#  77 (demand=0, load=0) ->  181 (demand=0, load=0) ->  174 (demand=0, load=0) ->  76 (demand=0, load=0) ->  235 (demand=0, load=0) ->  134 (demand=0, load=0) ->  265 (demand=0, load=0) ->  467 (demand=0, load=0) ->  473 (demand=0, load=0) ->  465 (demand=0, load=0) ->  606 (demand=0, load=0) ->  464 (demand=1, load=1) ->  483 (demand=0, load=1) ->  83 (demand=0, load=1) ->  470 (demand=0, load=1) ->  471 (demand=0, load=1) ->  68 (demand=0, load=1) ->  484 (demand=0, load=1) ->  71 (demand=0, load=1) ->  165 (demand=0, load=1) ->  70 (demand=0, load=1) ->  69 (demand=0, load=1) ->  215 (demand=0, load=1) ->  460 (demand=0, load=1) ->  187 (demand=0, load=1) ->  225 (demand=0, load=1) ->  205 (demand=0, load=1) ->  254 (demand=0, load=1) ->  177 (demand=0, load=1) ->  143 (demand=0, load=1) ->  183 (demand=0, load=1) ->  189 (demand=0, load=1) ->  206 (demand=0, load=1) ->  178 (demand=0, load=1) ->  175 (demand=0, load=1) ->  207 (demand=0, load=1) ->  141 (demand=0, load=1) ->  197 (demand=0, load=1) ->  200 (demand=0, load=1) ->  204 (demand=0, load=1) ->  551 (demand=0, load=1) ->  258 (demand=0, load=1) ->  259 (demand=0, load=1) ->  184 (demand=0, load=1) ->  119 (demand=0, load=1) ->  142 (demand=0, load=1) ->  474 (demand=0, load=1) ->  131 (demand=0, load=1) ->  150 (demand=0, load=1) ->  127 (demand=0, load=1) ->  182 (demand=0, load=1) ->  260 (demand=0, load=1) ->  199 (demand=0, load=1) ->  245 (demand=0, load=1) ->  151 (demand=0, load=1) ->  439 (demand=0, load=1) ->  438 (demand=0, load=1) ->  129 (demand=0, load=1) ->  186 (demand=0, load=1) ->  172 (demand=0, load=1) ->  472 (demand=0, load=1) ->  126 (demand=0, load=1) ->  239 (demand=0, load=1) ->  198 (demand=0, load=1) ->  122 (demand=0, load=1) ->  84 (demand=0, load=1) ->  437 (demand=0, load=1) ->  85 (demand=0, load=1) ->  57 (demand=0, load=1) ->  56 (demand=0, load=1) ->  58 (demand=0, load=1) ->  385 (demand=0, load=1) ->  383 (demand=0, load=1) ->  382 (demand=0, load=1) ->  384 (demand=0, load=1) ->  59 (demand=0, load=1) ->  571 (demand=0, load=1) ->  386 (demand=0, load=1) ->  381 (demand=0, load=1) ->  77 (demand=0, load=1)
# Distance of the route (model cost): 7296
# Load of the route: 1
#
#
# Total distance of all routes (model cost): 230223
# Total load of all routes: 4
#
# [CHECK] BIG_M kullanılan (yol yok) edge var mı?
#
# [UYARI] Aşağıdaki kenarlarda BIG_M kullanıldı (orijinal dm_raw'da mesafe <= 0):
#   Vehicle 0: 77 -> 453 | dm_raw[77,453] = 0.0
#   Vehicle 0: 452 -> 697 | dm_raw[452,697] = 0.0
#   Vehicle 0: 698 -> 109 | dm_raw[698,109] = 0.0
#   Vehicle 0: 494 -> 772 | dm_raw[494,772] = 0.0
#   Vehicle 0: 771 -> 459 | dm_raw[771,459] = 0.0
#   Vehicle 0: 443 -> 568 | dm_raw[443,568] = 0.0
#   Vehicle 0: 444 -> 686 | dm_raw[444,686] = 0.0
#   Vehicle 0: 691 -> 659 | dm_raw[691,659] = 0.0
#   Vehicle 0: 228 -> 422 | dm_raw[228,422] = 0.0
#   Vehicle 0: 420 -> 678 | dm_raw[420,678] = 0.0
#   Vehicle 0: 668 -> 163 | dm_raw[668,163] = 0.0
#   Vehicle 0: 230 -> 387 | dm_raw[230,387] = 0.0
#   Vehicle 0: 387 -> 0 | dm_raw[387,0] = 0.0
#   Vehicle 0: 820 -> 781 | dm_raw[820,781] = 0.0
#   Vehicle 0: 780 -> 581 | dm_raw[780,581] = 0.0
#   Vehicle 0: 580 -> 316 | dm_raw[580,316] = 0.0
#   Vehicle 0: 336 -> 794 | dm_raw[336,794] = 0.0
#   Vehicle 0: 782 -> 303 | dm_raw[782,303] = 0.0
#   Vehicle 0: 511 -> 607 | dm_raw[511,607] = 0.0
#   Vehicle 0: 379 -> 537 | dm_raw[379,537] = 0.0
#   Vehicle 0: 538 -> 202 | dm_raw[538,202] = 0.0
#   Vehicle 0: 17 -> 26 | dm_raw[17,26] = 0.0
#   Vehicle 0: 689 -> 616 | dm_raw[689,616] = 0.0
#   Vehicle 0: 128 -> 359 | dm_raw[128,359] = 0.0
#   Vehicle 0: 353 -> 718 | dm_raw[353,718] = 0.0
#   Vehicle 0: 709 -> 700 | dm_raw[709,700] = 0.0
#   Vehicle 0: 41 -> 654 | dm_raw[41,654] = 0.0
#   Vehicle 0: 261 -> 415 | dm_raw[261,415] = 0.0
#   Vehicle 0: 492 -> 690 | dm_raw[492,690] = 0.0
#   Vehicle 0: 16 -> 77 | dm_raw[16,77] = 0.0
#   Vehicle 1: 77 -> 658 | dm_raw[77,658] = 0.0
#   Vehicle 1: 821 -> 693 | dm_raw[821,693] = 0.0
#   Vehicle 1: 692 -> 430 | dm_raw[692,430] = 0.0
#   Vehicle 1: 430 -> 701 | dm_raw[430,701] = 0.0
#   Vehicle 1: 354 -> 648 | dm_raw[354,648] = 0.0
#   Vehicle 1: 358 -> 262 | dm_raw[358,262] = 0.0
#   Vehicle 1: 262 -> 595 | dm_raw[262,595] = 0.0
#   Vehicle 1: 703 -> 333 | dm_raw[703,333] = 0.0
#   Vehicle 1: 333 -> 462 | dm_raw[333,462] = 0.0
#   Vehicle 1: 413 -> 803 | dm_raw[413,803] = 0.0
#   Vehicle 1: 805 -> 766 | dm_raw[805,766] = 0.0
#   Vehicle 1: 765 -> 431 | dm_raw[765,431] = 0.0
#   Vehicle 1: 677 -> 507 | dm_raw[677,507] = 0.0
#   Vehicle 1: 505 -> 809 | dm_raw[505,809] = 0.0
#   Vehicle 1: 807 -> 468 | dm_raw[807,468] = 0.0
#   Vehicle 2: 77 -> 118 | dm_raw[77,118] = 0.0
#   Vehicle 2: 237 -> 213 | dm_raw[237,213] = 0.0
#   Vehicle 2: 684 -> 707 | dm_raw[684,707] = 0.0
#   Vehicle 2: 707 -> 89 | dm_raw[707,89] = 0.0
#   Vehicle 2: 734 -> 394 | dm_raw[734,394] = 0.0
#   Vehicle 2: 388 -> 378 | dm_raw[388,378] = 0.0
#   Vehicle 2: 378 -> 476 | dm_raw[378,476] = 0.0
#   Vehicle 2: 613 -> 390 | dm_raw[613,390] = 0.0
#   Vehicle 2: 399 -> 146 | dm_raw[399,146] = 0.0
#   Vehicle 2: 694 -> 612 | dm_raw[694,612] = 0.0
#   Vehicle 2: 612 -> 716 | dm_raw[612,716] = 0.0
#   Vehicle 2: 711 -> 116 | dm_raw[711,116] = 0.0
#   Vehicle 2: 738 -> 582 | dm_raw[738,582] = 0.0
#   Vehicle 2: 541 -> 515 | dm_raw[541,515] = 0.0
#   Vehicle 2: 742 -> 481 | dm_raw[742,481] = 0.0
#   Vehicle 2: 481 -> 727 | dm_raw[481,727] = 0.0
#   Vehicle 2: 253 -> 723 | dm_raw[253,723] = 0.0
#   Vehicle 2: 724 -> 97 | dm_raw[724,97] = 0.0
#   Vehicle 2: 404 -> 770 | dm_raw[404,770] = 0.0
#   Vehicle 2: 769 -> 801 | dm_raw[769,801] = 0.0
#   Vehicle 2: 791 -> 397 | dm_raw[791,397] = 0.0
#   Vehicle 2: 402 -> 560 | dm_raw[402,560] = 0.0
#   Vehicle 2: 36 -> 29 | dm_raw[36,29] = 0.0
#   Vehicle 2: 720 -> 369 | dm_raw[720,369] = 0.0
#   Vehicle 2: 93 -> 688 | dm_raw[93,688] = 0.0
#   Vehicle 2: 687 -> 590 | dm_raw[687,590] = 0.0
#   Vehicle 2: 673 -> 65 | dm_raw[673,65] = 0.0
#   Vehicle 3: 77 -> 181 | dm_raw[77,181] = 0.0
